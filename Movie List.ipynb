# %%
import pandas as pd
import numpy as np

# %%
data = pd.read_csv('main.csv')

# %%
data
# Out:
#           id      director_name                                actor_1_name  \
# 0      19995      James Cameron                             Sam Worthington
# 1        285     Gore Verbinski                                 Johnny Depp
# 2     206647         Sam Mendes                                Daniel Craig
# 3      49026  Christopher Nolan                              Christian Bale
# 4      49529     Andrew Stanton                               Taylor Kitsch
# ...      ...                ...                                         ...
# 5885  594767  David F. Sandberg                                Zachary Levi
# 5886  315162      Joel Crawford  Joel Crawford (director); Antonio Banderas
# 5887  696157       Kasi Lemmons                                 Naomi Ackie
# 5888    9381    Damien Chazelle                                   Brad Pitt
# 5889  937278       Marc Forster                                   Tom Hanks
#
#              actor_2_name       actor_3_name  \
# ...

# %%
movie_list = []
for i in range(len(data)):
    movie_list.append(data['movie_title'][i])

# %%
movie_list
# Out:
# ['avatar',
#  "pirates of the caribbean: at world's end",
#  'spectre',
#  'the dark knight rises',
#  'john carter',
#  'spider-man 3',
#  'tangled',
#  'avengers: age of ultron',
#  'harry potter and the half-blood prince',
#  'batman v superman: dawn of justice',
#  'superman returns',
#  'quantum of solace',
#  "pirates of the caribbean: dead man's chest",
#  'the lone ranger',
#  'man of steel',
#  'the chronicles of narnia: prince caspian',
#  'the avengers',
#  'pirates of the caribbean: on stranger tides',
#  'men in black 3',
#  'the hobbit: the battle of the five armies',
#  'the amazing spider-man',
#  'robin hood',
#  'the hobbit: the desolation of smaug',
#  'the golden compass',
#  'king kong',
#  'titanic',
#  'captain america: civil war',
#  'battleship',
#  'jurassic world',
#  'skyfall',
#  'spider-man 2',
#  'iron man 3',
#  'alice in wonderland',
#  'x-men: the last stand',
#  'monsters university',
#  'transformers: revenge of the fallen',
# ...
